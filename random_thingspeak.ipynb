# %%
import requests
import time

a=[45,13,89,44,22,100]
for x in a:
  r=requests.get('https://api.thingspeak.com/update?api_key=0ITH20RHSB88DPTS&field1='+ str(x))
  print(r.text)
  time.sleep(20)
# Out:
# 3
# 4
# 0
# 6
# 7
# 8

# %%
import random

for i in range(5):
  v=random.randint(0,100)
  r=requests.get('https://api.thingspeak.com/update?api_key=HZ0A78WQNG8K3M0Z&field1='+ str(v))
  print(r.text, v)
  time.sleep(20)
# Out:
# 0 67
# 0 74
# 0 43
# 0 53
# 0 54
